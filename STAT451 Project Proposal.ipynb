# %% [markdown]
# # Stat451 Project Proposal
# ## Group 12: Ahmad Latiffi, Nicholas Dubois, Gavin Frings, Nurul Sapari, Mariya Siddiqui
#
# ## Summary
# We will be analyzing airline on-time performance data sourced from the DOT’s Bureau of Transportation Statistics. We will be using this data to build models that predict the likelihood and duration of delays. We will also group airports/carriers based on similar delay patterns.
#
# ## Data
# As mentioned, our data source is the Bureau of Transportation Statistics’s report on carrier on-time performance (link). We will be using data from August 2023 as this is the latest data available, and the large number of entries (>600,000) per month limits the number of months we can analyze.
#
# The data includes variables on departure time and date, airline carrier, origin and destination airports, whether a flight was delayed 15+ minutes, total delay time, cancellation, and the sources of delays. We will use delay time and cancellation status for classification and regression analysis and look at the average of these variables for grouping airports and carriers.

# %%
import pandas as pd

df = pd.read_csv('./datasets/aug.csv')
print(f'Dataframe columns: {list(df.columns)}')
print(f'\nDataframe shape: {df.shape}')
df.head()
# Out:
# Dataframe columns: ['YEAR', 'MONTH', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'FL_DATE', 'OP_UNIQUE_CARRIER', 'OP_CARRIER_FL_NUM', 'ORIGIN', 'ORIGIN_CITY_NAME', 'ORIGIN_STATE_NM', 'DEST', 'DEST_STATE_ABR', 'DEST_STATE_NM', 'CRS_DEP_TIME', 'DEP_DELAY', 'DEP_DELAY_NEW', 'DEP_DEL15', 'CANCELLED', 'CARRIER_DELAY', 'WEATHER_DELAY', 'NAS_DELAY', 'SECURITY_DELAY', 'LATE_AIRCRAFT_DELAY']
#
# Dataframe shape: (602987, 23)
#    YEAR  MONTH  DAY_OF_MONTH  DAY_OF_WEEK               FL_DATE  \
# 0  2023      8             1            2  8/1/2023 12:00:00 AM
# 1  2023      8             1            2  8/1/2023 12:00:00 AM
# 2  2023      8             1            2  8/1/2023 12:00:00 AM
# 3  2023      8             1            2  8/1/2023 12:00:00 AM
# 4  2023      8             1            2  8/1/2023 12:00:00 AM
#
#   OP_UNIQUE_CARRIER  OP_CARRIER_FL_NUM ORIGIN ORIGIN_CITY_NAME  \
# 0                9E               4900    RIC     Richmond, VA
# 1                9E               4901    CLT    Charlotte, NC
# 2                9E               4901    JFK     New York, NY
# 3                9E               4902    SYR     Syracuse, NY
# 4                9E               4903    BHM   Birmingham, AL
#
#   ORIGIN_STATE_NM  ... CRS_DEP_TIME DEP_DELAY DEP_DELAY_NEW  DEP_DEL15  \
# 0        Virginia  ...          619      -4.0           0.0        0.0
# 1  North Carolina  ...         1955      -4.0           0.0        0.0
# 2        New York  ...         1629      -7.0           0.0        0.0
# 3        New York  ...          615     -11.0           0.0        0.0
# 4         Alabama  ...         1108      -5.0           0.0        0.0
#
#    CANCELLED  CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  SECURITY_DELAY  \
# 0        0.0            NaN            NaN        NaN             NaN
# 1        0.0            NaN            NaN        NaN             NaN
# 2        0.0            NaN            NaN        NaN             NaN
# 3        0.0            NaN            NaN        NaN             NaN
# 4        0.0            NaN            NaN        NaN             NaN
#
#    LATE_AIRCRAFT_DELAY
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Questions
# The questions we are looking to answer are as follows:
# - How effectively can we predict airline travel delays?
# - What factors give us the most explanatory power for predictions?
# - What airports/airlines show similar patterns/causes of delays?
# - What variables define these groupings?
#
# ## Methods
# To answer these questions we will use several machine learning analysis tools and techniques learned in the course. For the classification of delays and cancellations we will try and select the best of decision trees, SVMs, and logistic regression all using ensemble learning. For regression we will use and test linear regression and kNN regression. These methods will be tested and selected using CV and hyperparameter tuning. For grouping we will use K-means to cluster airports/carriers.
