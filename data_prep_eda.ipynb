# %% [markdown]
# # STAT 451 Final Project - Group 12 (11:00am)
# Mariya Siddiqui, Gavin Fring, Nicholas Dubois, Fiena Sapari, Ahmad Latiffi

# %% [markdown]
# ## Data Preparation, Exploration, and Transformation
# In this section, we do the following:
#
#  1. Load raw data (which is stored locally at `./datasets/airline_delays.csv`)
#  2. Run a rough profile of it to get an idea of what the dataset looks like as a whole, and on a columnar level. The profile numerical type columns (floats, ints, etc.) will also contain basic statistics about the values and distribution of that column. For categorical columns, these values are skipped.
#  3. Do some exploratory analysis of the raw dataset to get

# %%
# Imports
import pandas as pd

# Suppressing deprecation warnings temporarily as they take up a lot of room in output
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Load Data

# %%
df = pd.read_csv("./datasets/airline_delays.csv")
df.head(5)
# Out:
#    year  month carrier       carrier_name airport  \
# 0  2023      8      9E  Endeavor Air Inc.     ABE
# 1  2023      8      9E  Endeavor Air Inc.     ABY
# 2  2023      8      9E  Endeavor Air Inc.     AEX
# 3  2023      8      9E  Endeavor Air Inc.     AGS
# 4  2023      8      9E  Endeavor Air Inc.     ALB
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  Allentown/Bethlehem/Easton, PA: Lehigh Valley ...         89.0       13.0
# 1             Albany, GA: Southwest Georgia Regional         62.0       10.0
# 2           Alexandria, LA: Alexandria International         62.0       10.0
# 3        Augusta, GA: Augusta Regional at Bush Field         66.0       12.0
# 4                   Albany, NY: Albany International         92.0       22.0
#
#    carrier_ct  weather_ct  ...  security_ct  late_aircraft_ct  arr_cancelled  \
# 0        2.25        1.60  ...          0.0              5.99            2.0
# 1        1.97        0.04  ...          0.0              7.42            0.0
# 2        2.73        1.18  ...          0.0              4.28            1.0
# 3        3.69        2.27  ...          0.0              1.57            1.0
# 4        7.76        0.00  ...          0.0             11.28            2.0
#
#    arr_diverted  arr_delay  carrier_delay  weather_delay  nas_delay  \
# 0           1.0     1375.0           71.0          761.0      118.0
# 1           1.0      799.0          218.0            1.0       62.0
# 2           0.0      766.0           56.0          188.0       78.0
# 3           1.0     1397.0          471.0          320.0      388.0
# 4           0.0     1530.0          628.0            0.0      134.0
#
#    security_delay  late_aircraft_delay
# 0             0.0                425.0
# 1             0.0                518.0
# 2             0.0                444.0
# 3             0.0                218.0
# 4             0.0                768.0
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Profile Data

# %%
def dataframe_profile(df):
    '''
    This function creates a profile of a particular dataset given in the form of a dataframe. 
    It outputs a dataframe that contains the profile. 
    '''
    # Create a DataFrame to store the profile
    profile_df = pd.DataFrame(
        columns=[
            "Column",
            "Data Type",
            "Missing Values",
            "Unique Values",
            "Top Value",
            "Frequency",
            "Min",
            "25th Percentile",
            "Median",
            "75th Percentile",
            "Max",
            "Mean",
            "Standard Deviation",
        ]
    )

    # Populate the profile DataFrame
    for column in df.columns:
        data_type = df[column].dtype
        missing_values = df[column].isnull().sum()
        unique_values = df[column].nunique()
        top_value = df[column].mode().iloc[0] if unique_values > 0 else None
        frequency = df[column].value_counts().sort_values(ascending=False).iloc[0] if unique_values > 0 else None

        # Additional metadata for numeric columns
        if pd.api.types.is_numeric_dtype(df[column]):
            min_value = df[column].min()
            percentile_25 = df[column].quantile(0.25)
            median_value = df[column].median()
            percentile_75 = df[column].quantile(0.75)
            max_value = df[column].max()
            mean_value = df[column].mean()
            std_deviation = df[column].std()

        # No additional metadata for other types
        else:
            min_value = None
            percentile_25 = None
            median_value = None
            percentile_75 = None
            max_value = None

            mean_value = None
            std_deviation = None

        # Use loc to add rows to the DataFrame
        profile_df.loc[len(profile_df)] = {
            "Column": column,
            "Data Type": data_type,
            "Missing Values": missing_values,
            "Unique Values": unique_values,
            "Top Value": top_value,
            "Frequency": frequency,
            "Min": min_value,
            "25th Percentile": percentile_25,
            "Median": median_value,
            "75th Percentile": percentile_75,
            "Max": max_value,
            "Mean": mean_value,
            "Standard Deviation": std_deviation,
        }

    # Summary stats 
    (df_rows, df_columns) = df.shape
    print(f"The dataframe has {df_rows} rows and {df_columns} columns")

    return profile_df


result_profile = dataframe_profile(df)
display(result_profile)
# Out:
# The dataframe has 345323 rows and 21 columns
#                  Column Data Type  Missing Values  Unique Values  \
# 0                  year     int64               0             21
# 1                 month     int64               0             12
# 2               carrier    object               0             29
# 3          carrier_name    object               0             33
# 4               airport    object               0            420
# 5          airport_name    object               0            444
# 6           arr_flights   float64             509           7456
# 7             arr_del15   float64             747           2366
# 8            carrier_ct   float64             509          19260
# 9            weather_ct   float64             509           5766
# 10               nas_ct   float64             509          21760
# 11          security_ct   float64             509           1186
# 12     late_aircraft_ct   float64             509          23247
# 13        arr_cancelled   float64             509            688
# 14         arr_diverted   float64             509            140
# 15            arr_delay   float64             509          29612
# 16        carrier_delay   float64             509          15290
# 17        weather_delay   float64             509           5707
# 18            nas_delay   float64             509          14615
# 19       security_delay   float64             509            692
# 20  late_aircraft_delay   float64             509          18605
#
#                                   Top Value  Frequency   Min  25th Percentile  \
# 0                                      2019      20946  2003          2008.00
# 1                                         6      30098     1             4.00
# 2                                        OO      42164  None              NaN
# 3                     SkyWest Airlines Inc.      42164  None              NaN
# 4                                       DTW       3243  None              NaN
# 5   Detroit, MI: Detroit Metro Wayne County       3243  None              NaN
# 6                                      31.0       9864   1.0            58.00
# 7                                       0.0       9683   0.0             9.00
# 8                                       0.0      18747   0.0             3.00
# 9                                       0.0     136811   0.0             0.00
# 10                                      0.0      34190 -0.01             1.60
# 11                                      0.0     298673   0.0             0.00
# 12                                      0.0      41885   0.0             1.65
# 13                                      0.0     140192   0.0             0.00
# 14                                      0.0     249363   0.0             0.00
# 15                                      0.0       9921   0.0           436.00
# 16                                      0.0      18742   0.0           148.00
# 17                                      0.0     136783   0.0             0.00
# 18                                      0.0      34159 -19.0            54.00
# 19                                      0.0     298662   0.0             0.00
# 20                                      0.0      41879   0.0            80.00
#
#      Median  75th Percentile       Max         Mean  Standard Deviation
# 0   2013.00          2019.00      2023  2013.206213            6.042778
# 1      7.00             9.00        12     6.493312            3.431955
# 2       NaN              NaN      None          NaN                 NaN
# 3       NaN              NaN      None          NaN                 NaN
# 4       NaN              NaN      None          NaN                 NaN
# 5       NaN              NaN      None          NaN                 NaN
# 6    120.00           270.00   21977.0   378.935876         1021.719103
# 7     22.00            56.00    6377.0    73.002383          199.130487
# 8      8.15            19.76   1792.07    21.416112           48.984100
# 9      0.60             2.01    717.94     2.633833            9.906200
# 10     5.35            15.07   4091.27    23.581905           83.265625
# 11     0.00             0.00     80.56     0.181689            0.853906
# 12     5.85            17.05   2069.07    25.138513           76.050857
# 13     1.00             4.00    4951.0     7.209551           36.774197
# 14     0.00             1.00     256.0     0.871139            3.917271
# 15  1204.00          3102.00  438783.0  4284.516400        12808.591250
# 16   439.00          1118.00  196944.0  1333.480314         3744.297067
# 17    26.00           162.00   57707.0   226.415702          875.811434
# 18   199.00           595.00  238440.0  1085.411239         4538.254555
# 19     0.00             0.00    3760.0     7.456852           40.302272
# 20   354.00          1124.00  227959.0  1631.750196         5108.665467

# %% [markdown]
# Our categorical column "carrier", "carrier_name", "airport", and "airport_name" come in pairs. It would make sense that each pair would have the same number of unique values, but since the "name" columns have more in both cases, its clear that some "carrier" and "airport" values correspond to more than one possible naming of the location.
#
# Because of this naming inconsistency, we choose to use the identifying columns in our work instead of the names.

# %%
df_carrier_pairs = df[["carrier", "carrier_name"]].drop_duplicates(ignore_index=True)
display(df_carrier_pairs)

df_airport_pairs = df[["airport", "airport_name"]].drop_duplicates(ignore_index=True)
display(df_airport_pairs)
# Out:
#    carrier                  carrier_name
# 0       9E             Endeavor Air Inc.
# 1       AA        American Airlines Inc.
# 2       AS          Alaska Airlines Inc.
# 3       B6               JetBlue Airways
# 4       DL          Delta Air Lines Inc.
# 5       F9        Frontier Airlines Inc.
# 6       G4                 Allegiant Air
# 7       HA        Hawaiian Airlines Inc.
# 8       MQ                     Envoy Air
# 9       NK              Spirit Air Lines
# 10      OH             PSA Airlines Inc.
# 11      OO         SkyWest Airlines Inc.
# 12      UA         United Air Lines Inc.
# 13      WN        Southwest Airlines Co.
# 14      YX              Republic Airline
# 15      QX                   Horizon Air
# 16      YV            Mesa Airlines Inc.
# 17      EV       ExpressJet Airlines LLC
# 18      EV      ExpressJet Airlines Inc.
# 19      VX                Virgin America
# 20      US               US Airways Inc.
# 21      FL   AirTran Airways Corporation
# 22      MQ  American Eagle Airlines Inc.
# 23      9E        Pinnacle Airlines Inc.
# 24      EV   Atlantic Southeast Airlines
# 25      XE      ExpressJet Airlines Inc.
# 26      CO    Continental Air Lines Inc.
# 27      OH                   Comair Inc.
# 28      NW       Northwest Airlines Inc.
# 29      AQ           Aloha Airlines Inc.
# 30      TZ        ATA Airlines d/b/a ATA
# 31      RU      ExpressJet Airlines Inc.
# 32      DH              Independence Air
# 33      HP    America West Airlines Inc.
# 34      DH       Atlantic Coast Airlines
#     airport                                       airport_name
# 0       ABE  Allentown/Bethlehem/Easton, PA: Lehigh Valley ...
# 1       ABY             Albany, GA: Southwest Georgia Regional
# 2       AEX           Alexandria, LA: Alexandria International
# 3       AGS        Augusta, GA: Augusta Regional at Bush Field
# 4       ALB                   Albany, NY: Albany International
# ..      ...                                                ...
# 439     MKK                              Hoolehua, HI: Molokai
# 440     ILE                         Killeen, TX: Skylark Field
# 441     SKA                         Spokane, WA: Fairchild AFB
# 442     CBM                         Columbus, MS: Columbus AFB
# 443     DUT                     Unalaska, AK: Unalaska Airport
#
# [444 rows x 2 columns]

# %% [markdown]
# Some of the numerical columns have missing values. Running a profile on the rows with missing values tells us

# %%
missing_rows_df = df[df.isna().any(axis=1)]
missing_profile = dataframe_profile(missing_rows_df)
display(missing_profile)
# Out:
# The dataframe has 747 rows and 21 columns
#                  Column Data Type  Missing Values  Unique Values  \
# 0                  year     int64               0             21
# 1                 month     int64               0             12
# 2               carrier    object               0             26
# 3          carrier_name    object               0             29
# 4               airport    object               0            239
# 5          airport_name    object               0            243
# 6           arr_flights   float64             509             38
# 7             arr_del15   float64             747              0
# 8            carrier_ct   float64             509              1
# 9            weather_ct   float64             509              1
# 10               nas_ct   float64             509              1
# 11          security_ct   float64             509              1
# 12     late_aircraft_ct   float64             509              1
# 13        arr_cancelled   float64             509             38
# 14         arr_diverted   float64             509              4
# 15            arr_delay   float64             509              1
# 16        carrier_delay   float64             509              1
# 17        weather_delay   float64             509              1
# 18            nas_delay   float64             509              1
# 19       security_delay   float64             509              1
# 20  late_aircraft_delay   float64             509              1
#
#                                          Top Value Frequency   Min  \
# 0                                             2020       260  2003
# 1                                                4       195     1
# 2                                               OO       108  None
# 3                            SkyWest Airlines Inc.       108  None
# 4                                              PVD        10  None
# 5   Bristol/Johnson City/Kingsport, TN: Tri Cities        10  None
# 6                                              1.0        98   1.0
# 7                                             None      None   NaN
# 8                                              0.0       238   0.0
# 9                                              0.0       238   0.0
# 10                                             0.0       238   0.0
# 11                                             0.0       238   0.0
# 12                                             0.0       238   0.0
# 13                                             1.0        73   0.0
# 14                                             0.0       205   0.0
# 15                                             0.0       238   0.0
# 16                                             0.0       238   0.0
# 17                                             0.0       238   0.0
# 18                                             0.0       238   0.0
# 19                                             0.0       238   0.0
# 20                                             0.0       238   0.0
#
#     25th Percentile  Median  75th Percentile    Max         Mean  \
# 0            2009.0  2016.0          2020.00   2023  2014.693440
# 1               4.0     5.0             9.00     12     6.283802
# 2               NaN     NaN              NaN   None          NaN
# 3               NaN     NaN              NaN   None          NaN
# 4               NaN     NaN              NaN   None          NaN
# 5               NaN     NaN              NaN   None          NaN
# 6               1.0     2.0             8.75  120.0     8.689076
# 7               NaN     NaN              NaN    NaN          NaN
# 8               0.0     0.0             0.00    0.0     0.000000
# 9               0.0     0.0             0.00    0.0     0.000000
# 10              0.0     0.0             0.00    0.0     0.000000
# 11              0.0     0.0             0.00    0.0     0.000000
# 12              0.0     0.0             0.00    0.0     0.000000
# 13              1.0     2.0             8.00  120.0     8.521008
# 14              0.0     0.0             0.00    4.0     0.168067
# 15              0.0     0.0             0.00    0.0     0.000000
# 16              0.0     0.0             0.00    0.0     0.000000
# 17              0.0     0.0             0.00    0.0     0.000000
# 18              0.0     0.0             0.00    0.0     0.000000
# 19              0.0     0.0             0.00    0.0     0.000000
# 20              0.0     0.0             0.00    0.0     0.000000
#
#     Standard Deviation
# 0             5.873875
# 1             3.199328
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6            16.751975
# 7                  NaN
# 8             0.000000
# 9             0.000000
# 10            0.000000
# 11            0.000000
# 12            0.000000
# 13           16.801069
# 14            0.474129
# 15            0.000000
# 16            0.000000
# 17            0.000000
# 18            0.000000
# 19            0.000000
# 20            0.000000
