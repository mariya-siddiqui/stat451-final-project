# %% [markdown]
# # STAT 451 Final Project - Group 12 (11:00am)
# Mariya Siddiqui, Gavin Fring, Nicholas Dubois, Fiena Sapari, Ahmad Latiffi

# %% [markdown]
# ## Data Preparation, Exploration, and Transformation
# In this section, we do the following:
#
#  1. Load raw data (which is stored locally at `./datasets/airline_delays.csv`)
#  2. Run a rough profile of it to get an idea of what the dataset looks like as a whole, and on a columnar level. The profile numerical type columns (floats, ints, etc.) will also contain basic statistics about the values and distribution of that column. For categorical columns, these values are skipped.
#  3. Clean and prep the raw data to be consumable by our models

# %%
# Imports
import pandas as pd
import random

# Suppressing deprecation warnings temporarily as they take up a lot of room in output
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 1. Load Data

# %%
raw_df = pd.read_csv("./datasets/raw_airline_delays.csv")
raw_df.head(5)
# Out:
#    year  month carrier       carrier_name airport  \
# 0  2023      8      9E  Endeavor Air Inc.     ABE
# 1  2023      8      9E  Endeavor Air Inc.     ABY
# 2  2023      8      9E  Endeavor Air Inc.     AEX
# 3  2023      8      9E  Endeavor Air Inc.     AGS
# 4  2023      8      9E  Endeavor Air Inc.     ALB
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  Allentown/Bethlehem/Easton, PA: Lehigh Valley ...         89.0       13.0
# 1             Albany, GA: Southwest Georgia Regional         62.0       10.0
# 2           Alexandria, LA: Alexandria International         62.0       10.0
# 3        Augusta, GA: Augusta Regional at Bush Field         66.0       12.0
# 4                   Albany, NY: Albany International         92.0       22.0
#
#    carrier_ct  weather_ct  ...  security_ct  late_aircraft_ct  arr_cancelled  \
# 0        2.25        1.60  ...          0.0              5.99            2.0
# 1        1.97        0.04  ...          0.0              7.42            0.0
# 2        2.73        1.18  ...          0.0              4.28            1.0
# 3        3.69        2.27  ...          0.0              1.57            1.0
# 4        7.76        0.00  ...          0.0             11.28            2.0
#
#    arr_diverted  arr_delay  carrier_delay  weather_delay  nas_delay  \
# 0           1.0     1375.0           71.0          761.0      118.0
# 1           1.0      799.0          218.0            1.0       62.0
# 2           0.0      766.0           56.0          188.0       78.0
# 3           1.0     1397.0          471.0          320.0      388.0
# 4           0.0     1530.0          628.0            0.0      134.0
#
#    security_delay  late_aircraft_delay
# 0             0.0                425.0
# 1             0.0                518.0
# 2             0.0                444.0
# 3             0.0                218.0
# 4             0.0                768.0
#
# [5 rows x 21 columns]

# %% [markdown]
# ### 2. Profile Raw Data

# %%
def dataframe_profile(df):
    '''
    This function creates a profile of a particular dataset given in the form of a dataframe. 
    It outputs a dataframe that contains the profile. 
    '''
    # Create a DataFrame to store the profile
    profile_df = pd.DataFrame(
        columns=[
            "Column",
            "Data Type",
            "Missing Values",
            "Unique Values",
            "Top Value",
            "Frequency",
            "Min",
            "25th Percentile",
            "Median",
            "75th Percentile",
            "Max",
            "Mean",
            "Standard Deviation",
        ]
    )

    # Populate the profile DataFrame
    for column in df.columns:
        data_type = df[column].dtype
        missing_values = df[column].isnull().sum()
        unique_values = df[column].nunique()
        top_value = df[column].mode().iloc[0] if unique_values > 0 else None
        frequency = df[column].value_counts().sort_values(ascending=False).iloc[0] if unique_values > 0 else None

        # Additional metadata for numeric columns
        if pd.api.types.is_numeric_dtype(df[column]):
            min_value = df[column].min()
            percentile_25 = df[column].quantile(0.25)
            median_value = df[column].median()
            percentile_75 = df[column].quantile(0.75)
            max_value = df[column].max()
            mean_value = df[column].mean()
            std_deviation = df[column].std()

        # No additional metadata for other types
        else:
            min_value = None
            percentile_25 = None
            median_value = None
            percentile_75 = None
            max_value = None

            mean_value = None
            std_deviation = None

        # Use loc to add rows to the DataFrame
        profile_df.loc[len(profile_df)] = {
            "Column": column,
            "Data Type": data_type,
            "Missing Values": missing_values,
            "Unique Values": unique_values,
            "Top Value": top_value,
            "Frequency": frequency,
            "Min": min_value,
            "25th Percentile": percentile_25,
            "Median": median_value,
            "75th Percentile": percentile_75,
            "Max": max_value,
            "Mean": mean_value,
            "Standard Deviation": std_deviation,
        }

    # Summary stats 
    (df_rows, df_columns) = df.shape
    print(f"The dataframe has {df_rows} rows and {df_columns} columns")

    return profile_df

# %%
profile_raw_df = dataframe_profile(raw_df)
display(profile_raw_df)
# Out:
# The dataframe has 345323 rows and 21 columns
#                  Column Data Type  Missing Values  Unique Values  \
# 0                  year     int64               0             21
# 1                 month     int64               0             12
# 2               carrier    object               0             29
# 3          carrier_name    object               0             33
# 4               airport    object               0            420
# 5          airport_name    object               0            444
# 6           arr_flights   float64             509           7456
# 7             arr_del15   float64             747           2366
# 8            carrier_ct   float64             509          19260
# 9            weather_ct   float64             509           5766
# 10               nas_ct   float64             509          21760
# 11          security_ct   float64             509           1186
# 12     late_aircraft_ct   float64             509          23247
# 13        arr_cancelled   float64             509            688
# 14         arr_diverted   float64             509            140
# 15            arr_delay   float64             509          29612
# 16        carrier_delay   float64             509          15290
# 17        weather_delay   float64             509           5707
# 18            nas_delay   float64             509          14615
# 19       security_delay   float64             509            692
# 20  late_aircraft_delay   float64             509          18605
#
#                                   Top Value  Frequency   Min  25th Percentile  \
# 0                                      2019      20946  2003          2008.00
# 1                                         6      30098     1             4.00
# 2                                        OO      42164  None              NaN
# 3                     SkyWest Airlines Inc.      42164  None              NaN
# 4                                       DTW       3243  None              NaN
# 5   Detroit, MI: Detroit Metro Wayne County       3243  None              NaN
# 6                                      31.0       9864   1.0            58.00
# 7                                       0.0       9683   0.0             9.00
# 8                                       0.0      18747   0.0             3.00
# 9                                       0.0     136811   0.0             0.00
# 10                                      0.0      34190 -0.01             1.60
# 11                                      0.0     298673   0.0             0.00
# 12                                      0.0      41885   0.0             1.65
# 13                                      0.0     140192   0.0             0.00
# 14                                      0.0     249363   0.0             0.00
# 15                                      0.0       9921   0.0           436.00
# 16                                      0.0      18742   0.0           148.00
# 17                                      0.0     136783   0.0             0.00
# 18                                      0.0      34159 -19.0            54.00
# 19                                      0.0     298662   0.0             0.00
# 20                                      0.0      41879   0.0            80.00
#
#      Median  75th Percentile       Max         Mean  Standard Deviation
# 0   2013.00          2019.00      2023  2013.206213            6.042778
# 1      7.00             9.00        12     6.493312            3.431955
# 2       NaN              NaN      None          NaN                 NaN
# 3       NaN              NaN      None          NaN                 NaN
# 4       NaN              NaN      None          NaN                 NaN
# 5       NaN              NaN      None          NaN                 NaN
# 6    120.00           270.00   21977.0   378.935876         1021.719103
# 7     22.00            56.00    6377.0    73.002383          199.130487
# 8      8.15            19.76   1792.07    21.416112           48.984100
# 9      0.60             2.01    717.94     2.633833            9.906200
# 10     5.35            15.07   4091.27    23.581905           83.265625
# 11     0.00             0.00     80.56     0.181689            0.853906
# 12     5.85            17.05   2069.07    25.138513           76.050857
# 13     1.00             4.00    4951.0     7.209551           36.774197
# 14     0.00             1.00     256.0     0.871139            3.917271
# 15  1204.00          3102.00  438783.0  4284.516400        12808.591250
# 16   439.00          1118.00  196944.0  1333.480314         3744.297067
# 17    26.00           162.00   57707.0   226.415702          875.811434
# 18   199.00           595.00  238440.0  1085.411239         4538.254555
# 19     0.00             0.00    3760.0     7.456852           40.302272
# 20   354.00          1124.00  227959.0  1631.750196         5108.665467

# %% [markdown]
# ### 3. Refine raw data
# #### Categorical columns
# The categorical columns `carrier`, `carrier_name`, `airport`, and `airport_name` come in pairs. It would make sense that each pair would have the same number of unique values, but since the `_name` columns have more in both cases, its clear that some `carrier` and `airport` values correspond to more than one possible naming of the location.
#
# Because of this naming inconsistency, we choose to use the identifying columns `airport` and `carrier` as features to consider instead of the names.

# %%
df_carriers = raw_df[["carrier", "carrier_name"]]
df_carriers_cts = df_carriers.value_counts( sort=False).to_frame()
display(df_carriers_cts)
# Out:
#                                       count
# carrier carrier_name
# 9E      Endeavor Air Inc.              7593
#         Pinnacle Airlines Inc.         6454
# AA      American Airlines Inc.        21591
# AQ      Aloha Airlines Inc.             253
# AS      Alaska Airlines Inc.          14220
# B6      JetBlue Airways               12573
# CO      Continental Air Lines Inc.     6917
# DH      Atlantic Coast Airlines        1253
#         Independence Air                671
# DL      Delta Air Lines Inc.          29690
# EV      Atlantic Southeast Airlines   12204
#         ExpressJet Airlines Inc.      13159
#         ExpressJet Airlines LLC        1436
# F9      Frontier Airlines Inc.        13568
# FL      AirTran Airways Corporation    6956
# G4      Allegiant Air                  8280
# HA      Hawaiian Airlines Inc.         3881
# HP      America West Airlines Inc.     1581
# MQ      American Eagle Airlines Inc.  15409
#         Envoy Air                     11886
# NK      Spirit Air Lines               4698
# NW      Northwest Airlines Inc.        8084
# OH      Comair Inc.                    7775
#         PSA Airlines Inc.              6190
# OO      SkyWest Airlines Inc.         42164
# QX      Horizon Air                    1157
# RU      ExpressJet Airlines Inc.       4136
# TZ      ATA Airlines d/b/a ATA          924
# UA      United Air Lines Inc.         20794
# US      US Airways Inc.               10698
# VX      Virgin America                 1428
# WN      Southwest Airlines Co.        19181
# XE      ExpressJet Airlines Inc.       7375
# YV      Mesa Airlines Inc.            15417
# YX      Republic Airline               5727

# %%
df_airports = raw_df[["airport", "airport_name"]]
df_airports_cts = df_airports.value_counts( sort=False).to_frame()
display(df_airports_cts)
# Out:
#                                                             count
# airport airport_name
# ABE     Allentown/Bethlehem/Easton, PA: Lehigh Valley I...   1160
# ABI     Abilene, TX: Abilene Regional                         286
# ABQ     Albuquerque, NM: Albuquerque International Sunport   2452
# ABR     Aberdeen, SD: Aberdeen Regional                       140
# ABY     Albany, GA: Southwest Georgia Regional                247
# ...                                                           ...
# XWA     Williston, ND: Williston Basin International           47
# YAK     Yakutat, AK: Yakutat Airport                          243
# YKM     Yakima, WA: Yakima Air Terminal/McAllister Field       39
# YNG     Youngstown/Warren, OH: Youngstown-Warren Regional       1
# YUM     Yuma, AZ: Yuma MCAS/Yuma International                362
#
# [444 rows x 1 columns]

# %%
refined_df = raw_df.drop(["carrier_name", "airport_name"], axis=1)
refined_df.head()
# Out:
#    year  month carrier airport  arr_flights  arr_del15  carrier_ct  \
# 0  2023      8      9E     ABE         89.0       13.0        2.25
# 1  2023      8      9E     ABY         62.0       10.0        1.97
# 2  2023      8      9E     AEX         62.0       10.0        2.73
# 3  2023      8      9E     AGS         66.0       12.0        3.69
# 4  2023      8      9E     ALB         92.0       22.0        7.76
#
#    weather_ct  nas_ct  security_ct  late_aircraft_ct  arr_cancelled  \
# 0        1.60    3.16          0.0              5.99            2.0
# 1        0.04    0.57          0.0              7.42            0.0
# 2        1.18    1.80          0.0              4.28            1.0
# 3        2.27    4.47          0.0              1.57            1.0
# 4        0.00    2.96          0.0             11.28            2.0
#
#    arr_diverted  arr_delay  carrier_delay  weather_delay  nas_delay  \
# 0           1.0     1375.0           71.0          761.0      118.0
# 1           1.0      799.0          218.0            1.0       62.0
# 2           0.0      766.0           56.0          188.0       78.0
# 3           1.0     1397.0          471.0          320.0      388.0
# 4           0.0     1530.0          628.0            0.0      134.0
#
#    security_delay  late_aircraft_delay
# 0             0.0                425.0
# 1             0.0                518.0
# 2             0.0                444.0
# 3             0.0                218.0
# 4             0.0                768.0

# %% [markdown]
# #### Missing values
# Some of the numerical columns have missing values. Running a profile on the rows with missing values tells us that
#  1. the missing values aren't very strongly associated with any particular feature values
#  2. the number of samples with missing values (747) is *very* small compared to the total number of samples in the data set
#
# So, simply dropping the missing rows will suffice to prep the data set

# %%
missing_rows_df = refined_df[refined_df.isna().any(axis=1)]

profile_missing_rows_df = dataframe_profile(missing_rows_df)
display(profile_missing_rows_df)
# Out:
# The dataframe has 747 rows and 19 columns
#                  Column Data Type  Missing Values  Unique Values Top Value  \
# 0                  year     int64               0             21      2020
# 1                 month     int64               0             12         4
# 2               carrier    object               0             26        OO
# 3               airport    object               0            239       PVD
# 4           arr_flights   float64             509             38       1.0
# 5             arr_del15   float64             747              0      None
# 6            carrier_ct   float64             509              1       0.0
# 7            weather_ct   float64             509              1       0.0
# 8                nas_ct   float64             509              1       0.0
# 9           security_ct   float64             509              1       0.0
# 10     late_aircraft_ct   float64             509              1       0.0
# 11        arr_cancelled   float64             509             38       1.0
# 12         arr_diverted   float64             509              4       0.0
# 13            arr_delay   float64             509              1       0.0
# 14        carrier_delay   float64             509              1       0.0
# 15        weather_delay   float64             509              1       0.0
# 16            nas_delay   float64             509              1       0.0
# 17       security_delay   float64             509              1       0.0
# 18  late_aircraft_delay   float64             509              1       0.0
#
#    Frequency   Min  25th Percentile  Median  75th Percentile    Max  \
# 0        260  2003           2009.0  2016.0          2020.00   2023
# 1        195     1              4.0     5.0             9.00     12
# 2        108  None              NaN     NaN              NaN   None
# 3         10  None              NaN     NaN              NaN   None
# 4         98   1.0              1.0     2.0             8.75  120.0
# 5       None   NaN              NaN     NaN              NaN    NaN
# 6        238   0.0              0.0     0.0             0.00    0.0
# 7        238   0.0              0.0     0.0             0.00    0.0
# 8        238   0.0              0.0     0.0             0.00    0.0
# 9        238   0.0              0.0     0.0             0.00    0.0
# 10       238   0.0              0.0     0.0             0.00    0.0
# 11        73   0.0              1.0     2.0             8.00  120.0
# 12       205   0.0              0.0     0.0             0.00    4.0
# 13       238   0.0              0.0     0.0             0.00    0.0
# 14       238   0.0              0.0     0.0             0.00    0.0
# 15       238   0.0              0.0     0.0             0.00    0.0
# 16       238   0.0              0.0     0.0             0.00    0.0
# 17       238   0.0              0.0     0.0             0.00    0.0
# 18       238   0.0              0.0     0.0             0.00    0.0
#
#            Mean  Standard Deviation
# 0   2014.693440            5.873875
# 1      6.283802            3.199328
# 2           NaN                 NaN
# 3           NaN                 NaN
# 4      8.689076           16.751975
# 5           NaN                 NaN
# 6      0.000000            0.000000
# 7      0.000000            0.000000
# 8      0.000000            0.000000
# 9      0.000000            0.000000
# 10     0.000000            0.000000
# 11     8.521008           16.801069
# 12     0.168067            0.474129
# 13     0.000000            0.000000
# 14     0.000000            0.000000
# 15     0.000000            0.000000
# 16     0.000000            0.000000
# 17     0.000000            0.000000
# 18     0.000000            0.000000

# %%
df_carrier_counts = refined_df[["carrier"]].value_counts().to_frame()
df_missing_carrier_counts = missing_rows_df[["carrier"]].value_counts().to_frame()
df_joined_carrier_counts = df_carrier_counts.join(df_missing_carrier_counts, how="outer", lsuffix="_raw", rsuffix="_missing")
df_joined_carrier_counts = df_joined_carrier_counts.assign(prop_missing=df_joined_carrier_counts["count_missing"] / df_joined_carrier_counts["count_raw"])
display(df_joined_carrier_counts[df_joined_carrier_counts.notnull().all(axis=1)])
# Out:
#          count_raw  count_missing  prop_missing
# carrier
# 9E           14047           54.0      0.003844
# AA           21591           11.0      0.000509
# AS           14220            2.0      0.000141
# B6           12573            8.0      0.000636
# CO            6917            9.0      0.001301
# DH            1924            1.0      0.000520
# DL           29690           65.0      0.002189
# EV           26799          103.0      0.003843
# F9           13568           32.0      0.002358
# FL            6956            1.0      0.000144
# G4            8280           63.0      0.007609
# HA            3881            1.0      0.000258
# HP            1581            2.0      0.001265
# MQ           27295           32.0      0.001172
# NK            4698            9.0      0.001916
# NW            8084           16.0      0.001979
# OH           13965           97.0      0.006946
# OO           42164          108.0      0.002561
# RU            4136            2.0      0.000484
# TZ             924            6.0      0.006494
# UA           20794           35.0      0.001683
# US           10698            6.0      0.000561
# VX            1428            3.0      0.002101
# XE            7375            9.0      0.001220
# YV           15417           47.0      0.003049
# YX            5727           25.0      0.004365

# %%
df_airport_counts = refined_df[["airport"]].value_counts().to_frame()
df_missing_airport_counts = missing_rows_df[["airport"]].value_counts().to_frame()
df_joined_airport_counts = df_airport_counts.join(df_missing_airport_counts, how="outer", lsuffix="_raw", rsuffix="_missing")
df_joined_airport_counts = df_joined_airport_counts.assign(prop_missing=df_joined_airport_counts["count_missing"] / df_joined_airport_counts["count_raw"])
display(df_joined_airport_counts[df_joined_airport_counts.notnull().all(axis=1)])
# Out:
#          count_raw  count_missing  prop_missing
# airport
# ABE           1160            3.0      0.002586
# ABI            286            4.0      0.013986
# ABQ           2452            4.0      0.001631
# ABY            247            2.0      0.008097
# ACY            229            9.0      0.039301
# ...            ...            ...           ...
# TYS           1623            1.0      0.000616
# VCT             61            1.0      0.016393
# VLD            244            1.0      0.004098
# VPS           1215            3.0      0.002469
# XNA           1550            4.0      0.002581
#
# [239 rows x 3 columns]

# %%
refined_df = refined_df.dropna(axis=0, how="any", ignore_index=True)
refined_df.head()
# Out:
#    year  month carrier airport  arr_flights  arr_del15  carrier_ct  \
# 0  2023      8      9E     ABE         89.0       13.0        2.25
# 1  2023      8      9E     ABY         62.0       10.0        1.97
# 2  2023      8      9E     AEX         62.0       10.0        2.73
# 3  2023      8      9E     AGS         66.0       12.0        3.69
# 4  2023      8      9E     ALB         92.0       22.0        7.76
#
#    weather_ct  nas_ct  security_ct  late_aircraft_ct  arr_cancelled  \
# 0        1.60    3.16          0.0              5.99            2.0
# 1        0.04    0.57          0.0              7.42            0.0
# 2        1.18    1.80          0.0              4.28            1.0
# 3        2.27    4.47          0.0              1.57            1.0
# 4        0.00    2.96          0.0             11.28            2.0
#
#    arr_diverted  arr_delay  carrier_delay  weather_delay  nas_delay  \
# 0           1.0     1375.0           71.0          761.0      118.0
# 1           1.0      799.0          218.0            1.0       62.0
# 2           0.0      766.0           56.0          188.0       78.0
# 3           1.0     1397.0          471.0          320.0      388.0
# 4           0.0     1530.0          628.0            0.0      134.0
#
#    security_delay  late_aircraft_delay
# 0             0.0                425.0
# 1             0.0                518.0
# 2             0.0                444.0
# 3             0.0                218.0
# 4             0.0                768.0

# %% [markdown]
# #### Re-profile refined data
# and save to csv for easy usage in models

# %%
profile_refined_df = dataframe_profile(refined_df)
display(profile_refined_df)
# Out:
# The dataframe has 344576 rows and 19 columns
#                  Column Data Type  Missing Values  Unique Values Top Value  \
# 0                  year     int64               0             21      2019
# 1                 month     int64               0             12         6
# 2               carrier    object               0             29        OO
# 3               airport    object               0            418       DTW
# 4           arr_flights   float64               0           7456      31.0
# 5             arr_del15   float64               0           2366       0.0
# 6            carrier_ct   float64               0          19260       0.0
# 7            weather_ct   float64               0           5766       0.0
# 8                nas_ct   float64               0          21760       0.0
# 9           security_ct   float64               0           1186       0.0
# 10     late_aircraft_ct   float64               0          23247       0.0
# 11        arr_cancelled   float64               0            688       0.0
# 12         arr_diverted   float64               0            140       0.0
# 13            arr_delay   float64               0          29612       0.0
# 14        carrier_delay   float64               0          15290       0.0
# 15        weather_delay   float64               0           5707       0.0
# 16            nas_delay   float64               0          14615       0.0
# 17       security_delay   float64               0            692       0.0
# 18  late_aircraft_delay   float64               0          18605       0.0
#
#     Frequency   Min  25th Percentile   Median  75th Percentile       Max  \
# 0       20927  2003          2008.00  2013.00          2019.00      2023
# 1       30045     1             4.00     7.00             9.00        12
# 2       42056  None              NaN      NaN              NaN      None
# 3        3243  None              NaN      NaN              NaN      None
# 4        9863   1.0            58.00   120.00           270.00   21977.0
# 5        9683   0.0             9.00    22.00            56.00    6377.0
# 6       18509   0.0             3.00     8.16            19.77   1792.07
# 7      136573   0.0             0.00     0.60             2.02    717.94
# 8       33952 -0.01             1.61     5.35            15.08   4091.27
# 9      298435   0.0             0.00     0.00             0.00     80.56
# 10      41647   0.0             1.66     5.86            17.06   2069.07
# 11     140165   0.0             0.00     1.00             4.00    4951.0
# 12     249158   0.0             0.00     0.00             1.00     256.0
# 13       9683   0.0           437.00  1206.00          3104.00  438783.0
# 14      18504   0.0           148.00   439.00          1118.00  196944.0
# 15     136545   0.0             0.00    26.00           163.00   57707.0
# 16      33921 -19.0            54.00   199.00           595.00  238440.0
# 17     298424   0.0             0.00     0.00             0.00    3760.0
# 18      41641   0.0            80.00   355.00          1125.00  227959.0
#
#            Mean  Standard Deviation
# 0   2013.202989            6.042750
# 1      6.493766            3.432433
# 2           NaN                 NaN
# 3           NaN                 NaN
# 4    379.191606         1022.025448
# 5     73.002383          199.130487
# 6     21.430904           48.997779
# 7      2.635652            9.909379
# 8     23.598193           83.292069
# 9      0.181815            0.854187
# 10    25.155876           76.074246
# 11     7.208645           36.784240
# 12     0.871625            3.918560
# 13  4287.475732        12812.518837
# 14  1334.401354         3745.425879
# 15   226.572089          876.093624
# 16  1086.160937         4539.731899
# 17     7.462003           40.315711
# 18  1632.877252         5110.249394

# %%
refined_df.to_csv("./datasets/refined_airline_delays.csv", index=False)
